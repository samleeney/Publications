# %% [markdown]
# # Bayesian RFI Mitigation - Example
# This is a simple script showing how to integrate a likelihood capable of correcting for RFI into a Bayesian data analysis pipeline.

# %%
First, generate some mock data.

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 25
x = np.linspace(0, 25, N)
m = 1
c = 1
sig = 5
y = m * x + c + np.random.randn(N) * sig
plt.plot(x, y, 'o')

# %% [markdown]
# Add some RFI

# %%
y[10] += 100
y[15] += 100
plt.plot(x, y, 'ro')

# %% [markdown]
# Now, define a traditional likelihood function and fit the data without modeling the RFI.

# %%
def likelihood(theta):
    m=theta[0]
    c=theta[1]
    sig=theta[2]
    y_=m * x + c
    return (-(y_-y)**2/sig**2/2 - np.log(2*np.pi*sig**2)/2).sum(), []

# %% [markdown]
# Now, we'll define a likelihood function that can correct for RFI.
#  Note the difference between the two likelihoods. Notice the condition imposed on the likelihood by `emax'.

# %%
def rfi_corrected_likelihood(theta):
    m=theta[0]
    c=theta[1]
    sig=theta[2]
    y_= m * x + c
    logL=-(y_-y)**2/sig**2/2 - np.log(2*np.pi*sig**2)/2 + np.log(1-p)
    emax = logL > logp - np.log(delta)
    logPmax=np.where(emax, logL, logp - np.log(delta)).sum()
    return logPmax, []

# %% [markdown]
# Definte a prior. Notice that the prior range which encapsulates the full range of possible values from the data as defined by delta.

# %%
from pypolychord.priors import UniformPrior

def prior(hypercube):
    theta = np.zeros_like(hypercube)
    theta[0]=UniformPrior(-delta/(np.max(x)-np.min(x)), delta/(np.max(x)-np.min(x)))(hypercube[1])  # m
    theta[1] = UniformPrior(-delta, delta)(hypercube[0])  # c
    theta[2]=UniformPrior(0, delta)(hypercube[2])  # sig
    return theta

# %% [markdown]
# Set $p$ (the probability thresholding term) and $\Delta$ (the length scale in units of data)

# %%
delta = np.max(y)
logp = -2.5
p = np.exp(logp)

# %% [markdown]
# Fit with a Bayesian numerical solver. We use the Nested Sampler Polychord but any others will also work.
#  Polychord settings.

# %%
import pypolychord
from pypolychord.settings import PolyChordSettings

nDims=3
nDerived=0
settings=PolyChordSettings(nDims, nDerived)
settings.nlive=200
settings.read_resume=False

# %% [markdown]
# We first fit the data using the traditional likelihood

# %%
settings.file_root='rfi_nocorr'
output=pypolychord.run_polychord(
likelihood, nDims, nDerived, settings, prior)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.20.1
#   release: 1st June 2021
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :       3
# nDerived :       0
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/rfi_nocorr.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.650E-04 seconds
# number of repeats:           15
# started sampling
#
# _________________
# lives      | 200 |
# phantoms   |1891 |
# posteriors | 201 |
# equals     |  17 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 201
# nposterior =                 201
# nequals    =                  17
# nlike      =                4876
# <nlike>    =          23.38   (           1.56 per slice )
# log(Z)     =         -147.42 +/-  0.18
# log(Z_1)   =         -147.42 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2508 |
# posteriors | 402 |
# equals     |  36 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 402
# nposterior =                 402
# nequals    =                  34
# nlike      =               14819
# <nlike>    =          49.72   (           3.31 per slice )
# log(Z)     =         -139.07 +/-  0.14
# log(Z_1)   =         -139.07 +/-  0.14 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2614 |
# posteriors | 603 |
# equals     |  29 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 603
# nposterior =                 603
# nequals    =                  36
# nlike      =               26416
# <nlike>    =          57.98   (           3.87 per slice )
# log(Z)     =         -133.42 +/-  0.15
# log(Z_1)   =         -133.42 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2968 |
# posteriors | 804 |
# equals     |  81 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 804
# nposterior =                 804
# nequals    =                  84
# nlike      =               39329
# <nlike>    =          64.56   (           4.30 per slice )
# log(Z)     =         -130.05 +/-  0.14
# log(Z_1)   =         -130.05 +/-  0.14 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2932 |
# posteriors |1005 |
# equals     | 117 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1005
# nposterior =                1005
# nequals    =                 108
# nlike      =               53048
# <nlike>    =          68.59   (           4.57 per slice )
# log(Z)     =         -127.87 +/-  0.15
# log(Z_1)   =         -127.87 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |3029 |
# posteriors |1206 |
# equals     | 204 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1206
# nposterior =                1206
# nequals    =                 211
# nlike      =               67357
# <nlike>    =          71.55   (           4.77 per slice )
# log(Z)     =         -126.51 +/-  0.15
# log(Z_1)   =         -126.51 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2441 |
# posteriors |1407 |
# equals     | 319 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1407
# nposterior =                1407
# nequals    =                 312
# nlike      =               81688
# <nlike>    =          71.66   (           4.78 per slice )
# log(Z)     =         -125.68 +/-  0.16
# log(Z_1)   =         -125.68 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2749 |
# posteriors |1608 |
# equals     | 483 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1608
# nposterior =                1608
# nequals    =                 465
# nlike      =               96158
# <nlike>    =          72.35   (           4.82 per slice )
# log(Z)     =         -125.27 +/-  0.16
# log(Z_1)   =         -125.27 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2981 |
# posteriors |1809 |
# equals     | 579 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1809
# nposterior =                1809
# nequals    =                 555
# nlike      =              110743
# <nlike>    =          72.92   (           4.86 per slice )
# log(Z)     =         -125.10 +/-  0.16
# log(Z_1)   =         -125.10 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2756 |
# posteriors |2010 |
# equals     | 619 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2010
# nposterior =                2010
# nequals    =                 585
# nlike      =              125062
# <nlike>    =          71.59   (           4.77 per slice )
# log(Z)     =         -125.03 +/-  0.16
# log(Z_1)   =         -125.03 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2793 |
# posteriors |2211 |
# equals     | 633 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2211
# nposterior =                2211
# nequals    =                 601
# nlike      =              139556
# <nlike>    =          72.47   (           4.83 per slice )
# log(Z)     =         -125.00 +/-  0.17
# log(Z_1)   =         -125.00 +/-  0.17 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2728 |
# posteriors |2412 |
# equals     | 638 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2412
# nposterior =                2412
# nequals    =                 607
# nlike      =              154015
# <nlike>    =          72.30   (           4.82 per slice )
# log(Z)     =         -124.99 +/-  0.17
# log(Z_1)   =         -124.99 +/-  0.17 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |3007 |
# posteriors |2613 |
# equals     | 641 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2613
# nposterior =                2613
# nequals    =                 607
# nlike      =              168465
# <nlike>    =          72.25   (           4.82 per slice )
# log(Z)     =         -124.99 +/-  0.17
# log(Z_1)   =         -124.99 +/-  0.17 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         2978                              |
# | log(Z) =         -124.98654 +/-            0.16569 |
# |____________________________________________________|

# %% [markdown]
# Process the results using anesthetic. Again, any other chains processor could be used here.

# %%
from anesthetic import NestedSamples
norfi_nocorr=NestedSamples(
    root = './chains/rfi_nocorr', columns = ['$m$', '$c$', r'$\sigma$'])
fig, ax=norfi_nocorr.plot_2d(['$m$', '$c$', r'$\sigma$'],
                               label = 'RFI No Correction', alpha = 0.6)

# %% [markdown]
# Notice that $\sigma$ is estimated completely wrong, and the confidence in the other parameters is low.

# %% [markdown]
# Fit the data, this time using the correcting likelihood

# %%
settings.file_root='rfi_corr'
output=pypolychord.run_polychord(
    rfi_corrected_likelihood, nDims, nDerived, settings, prior)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.20.1
#   release: 1st June 2021
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :       3
# nDerived :       0
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/rfi_corr.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.153E-03 seconds
# number of repeats:           15
# started sampling
#
# _________________
# lives      | 200 |
# phantoms   |1803 |
# posteriors | 201 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 203
# nposterior =                 201
# nequals    =                  23
# nlike      =                5019
# <nlike>    =          24.09   (           1.61 per slice )
# log(Z)     =         -147.12 +/-  0.16
# log(Z_1)   =         -147.12 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2243 |
# posteriors | 402 |
# equals     |  27 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 404
# nposterior =                 402
# nequals    =                  32
# nlike      =               15052
# <nlike>    =          50.16   (           3.34 per slice )
# log(Z)     =         -138.32 +/-  0.16
# log(Z_1)   =         -138.32 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2493 |
# posteriors | 603 |
# equals     |  27 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 605
# nposterior =                 603
# nequals    =                  31
# nlike      =               26861
# <nlike>    =          59.05   (           3.94 per slice )
# log(Z)     =         -132.25 +/-  0.15
# log(Z_1)   =         -132.25 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2645 |
# posteriors | 804 |
# equals     |  37 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 806
# nposterior =                 804
# nequals    =                  36
# nlike      =               39461
# <nlike>    =          63.00   (           4.20 per slice )
# log(Z)     =         -126.10 +/-  0.17
# log(Z_1)   =         -126.10 +/-  0.17 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2826 |
# posteriors |1005 |
# equals     |  40 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1007
# nposterior =                1005
# nequals    =                  27
# nlike      =               52960
# <nlike>    =          67.50   (           4.50 per slice )
# log(Z)     =         -120.16 +/-  0.18
# log(Z_1)   =         -120.16 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2974 |
# posteriors |1206 |
# equals     |  42 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1208
# nposterior =                1206
# nequals    =                  40
# nlike      =               66945
# <nlike>    =          69.92   (           4.66 per slice )
# log(Z)     =         -115.15 +/-  0.19
# log(Z_1)   =         -115.15 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |3052 |
# posteriors |1407 |
# equals     |  51 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1409
# nposterior =                1407
# nequals    =                  48
# nlike      =               81029
# <nlike>    =          70.42   (           4.69 per slice )
# log(Z)     =         -110.92 +/-  0.19
# log(Z_1)   =         -110.92 +/-  0.19 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2882 |
# posteriors |1608 |
# equals     |  60 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1610
# nposterior =                1608
# nequals    =                  59
# nlike      =               95317
# <nlike>    =          71.44   (           4.76 per slice )
# log(Z)     =         -106.86 +/-  0.20
# log(Z_1)   =         -106.86 +/-  0.20 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2878 |
# posteriors |1809 |
# equals     |  92 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1811
# nposterior =                1809
# nequals    =                  77
# nlike      =              109744
# <nlike>    =          72.14   (           4.81 per slice )
# log(Z)     =         -103.95 +/-  0.21
# log(Z_1)   =         -103.95 +/-  0.21 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2614 |
# posteriors |2010 |
# equals     | 120 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2012
# nposterior =                2010
# nequals    =                 125
# nlike      =              124181
# <nlike>    =          72.19   (           4.81 per slice )
# log(Z)     =         -101.91 +/-  0.21
# log(Z_1)   =         -101.91 +/-  0.21 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2977 |
# posteriors |2211 |
# equals     | 261 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2213
# nposterior =                2211
# nequals    =                 253
# nlike      =              138757
# <nlike>    =          72.88   (           4.86 per slice )
# log(Z)     =         -100.75 +/-  0.22
# log(Z_1)   =         -100.75 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2858 |
# posteriors |2412 |
# equals     | 447 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2414
# nposterior =                2412
# nequals    =                 441
# nlike      =              153043
# <nlike>    =          71.43   (           4.76 per slice )
# log(Z)     =         -100.20 +/-  0.22
# log(Z_1)   =         -100.20 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2751 |
# posteriors |2613 |
# equals     | 584 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2615
# nposterior =                2613
# nequals    =                 575
# nlike      =              167382
# <nlike>    =          71.70   (           4.78 per slice )
# log(Z)     =          -99.93 +/-  0.22
# log(Z_1)   =          -99.93 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2713 |
# posteriors |2814 |
# equals     | 645 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2816
# nposterior =                2814
# nequals    =                 658
# nlike      =              181803
# <nlike>    =          72.11   (           4.81 per slice )
# log(Z)     =          -99.82 +/-  0.22
# log(Z_1)   =          -99.82 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2945 |
# posteriors |3015 |
# equals     | 683 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3017
# nposterior =                3015
# nequals    =                 688
# nlike      =              196330
# <nlike>    =          72.64   (           4.84 per slice )
# log(Z)     =          -99.77 +/-  0.22
# log(Z_1)   =          -99.77 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2731 |
# posteriors |3216 |
# equals     | 697 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3218
# nposterior =                3216
# nequals    =                 705
# nlike      =              210764
# <nlike>    =          72.17   (           4.81 per slice )
# log(Z)     =          -99.75 +/-  0.22
# log(Z_1)   =          -99.75 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2775 |
# posteriors |3417 |
# equals     | 700 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3419
# nposterior =                3417
# nequals    =                 707
# nlike      =              225155
# <nlike>    =          71.95   (           4.80 per slice )
# log(Z)     =          -99.75 +/-  0.22
# log(Z_1)   =          -99.75 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      | 200 |
# phantoms   |2897 |
# posteriors |3618 |
# equals     | 701 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3620
# nposterior =                3618
# nequals    =                 707
# nlike      =              239681
# <nlike>    =          72.63   (           4.84 per slice )
# log(Z)     =          -99.74 +/-  0.22
# log(Z_1)   =          -99.74 +/-  0.22 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         3904                              |
# | log(Z) =          -99.74234 +/-            0.22339 |
# |____________________________________________________|

# %% [markdown]
# Compare the results,

# %%
from anesthetic import NestedSamples
rfi_corr=NestedSamples(
    root = './chains/rfi_corr', columns = ['$m$', '$c$', r'$\sigma$'])
fig, ax=norfi_nocorr.plot_2d(['$m$', '$c$', r'$\sigma$'],
                               label = 'No RFI No Correction', alpha = 0.6)
rfi_corr.plot_2d(ax, label = 'RFI Corrected', alpha = 0.6)
plt.legend(loc='upper right', markerscale=5,
           bbox_to_anchor=(1.3, 1.6), fontsize=7)
# Out:
# /home/sam/.local/lib/python3.10/site-packages/anesthetic-2.0.0b12-py3.10.egg/anesthetic/samples.py:750: RuntimeWarning: 2 out of 3904 samples have logL <= logL_birth,
# 2 of which have logL == logL_birth.
# This may just indicate numerical rounding errors at the peak of the likelihood, but further investigation of the chains files is recommended.
# Dropping the invalid samples.
#   warnings.warn("%i out of %i samples have logL <= logL_birth,"

# %% [markdown]
# # Key Point
#
# The vast majority of this example makes up the general 'pipeline' for simulating and analysing the data. Only three lines of code are modified (inside rfi_corrected_likelihood) to impliment the RFI correction.
